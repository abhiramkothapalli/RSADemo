# %%
from notebook.auth import passwd
passwd()
# Out:
# Enter password: ········
# Verify password: ········
# 'sha1:0d4daf0f5aea:b397539bcc902aaabb08fa45b0d1a86d4e337b84'

# %% [markdown]
# ## Setting up base numbers

# %%
p_1 = 53
p_2 = 59
n = p_1 * p_2

print n
# Out:
# 3127

# %%
def phi(p1, p2):
    return (p1-1) * (p2-1)

phi(p_1, p_2)
# Out:
# 3016

# %% [markdown]
# ## Public exponents e

# %%
# Public exponents e needs to statified the following conditions
# 1 < e < ϕ(n)
# e must be an odd number
# e and ϕ(n) are coprimes, meaning that e does not share a factor with ϕ(n)

e = 17  

#seems reasonable right?

# %% [markdown]
# ## Modular Arithmetics

# %%
c = 209**17 % 3127

# %% [markdown]
# ## How big is the prime number?

# %%
print 2817**2129
# Out:
# ...

# %%
print 209 % 3127
# Out:
# 209
